# %%
import pyforest
import tensorflow as tf
import keras

# %%
from keras.preprocessing.image import array_to_img, ImageDataGenerator, img_to_array, load_img

# %%
GenrataeImage = ImageDataGenerator(rotation_range=40, width_shift_range= .2, 
                                   height_shift_range=.2, shear_range=0.2,
                                  zoom_range=.2, horizontal_flip=True, fill_mode="nearest")

# %%
img = load_img(r'C:\Users\shubh\OneDrive\Pictures\Camera Roll\WIN_20211123_10_50_38_Pro.jpg')

# %%
plt.imshow(img, cmap = 'gray')

# %%
x = img_to_array(img)

# %%
x = x.reshape((1, ) + x.shape) # reshape it

# %%
i = 0
for batch in GenrataeImage.flow(x ,batch_size=1, save_to_dir = r"C:\Users\shubh\Pranjal Sir class\OpenCv\Preview_images", save_prefix='dd', save_format='PNG'):
    i = i+1
    if i > 500:
        break
